# %% [markdown]
# # 01. Data Collection
#
# In this notebook, we will download and conduct our initial inspection of the datasets needed for this project:
# 1. **Fraud Detection Dataset**: Kaggle Credit Card Fraud Dataset
# 2. **Financial Prediction Dataset**: Stock market data via Yahoo Finance (or Lending Club defaults)
#
# ## 1. Environment Setup

# %%
import os
import pandas as pd
import yfinance as yf

# Ensure data directories exist
os.makedirs('../data/raw', exist_ok=True)
os.makedirs('../data/processed', exist_ok=True)

# %% [markdown]
# ## 2. Fraud Detection Data (Credit Card Dataset)
#
# You can download this dataset from Kaggle:
# - Link: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
#
# Place `creditcard.csv` in your `data/raw/` directory.

# %%
# fraud_path = '../data/raw/creditcard.csv'
# if os.path.exists(fraud_path):
#     df_fraud = pd.read_csv(fraud_path)
#     display(df_fraud.head())
# else:
#     print('Please download creditcard.csv from Kaggle and place it in the data/raw/ directory.')

# %% [markdown]
# ## 3. Financial Prediction Data (Yahoo Finance)
# We will fetch daily historical data for an arbitrary stock ticker (e.g., SPY or TSLA).

# %%
# TICKER = 'SPY'
# df_finance = yf.download(TICKER, start='2015-01-01', end='2023-01-01')
# df_finance.to_csv(f'../data/raw/{TICKER}_daily.csv')
# df_finance.head()
